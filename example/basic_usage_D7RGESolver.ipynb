# %% [markdown]
# ## Import stuff of D7RGESolver

# %%
import numpy as np
import sys
import os
sys.path.append("..")  
import matplotlib.pyplot as plt
from RGE_dim7 import solve_rge, print_WCs
# %matplotlib inline

# %% [markdown]
# ## Solve RGEs using D7RGESolver

# %% [markdown]
# #### Choose the down-quark flavor basis and accurate integrated method (funtion solve_reg) to solve the RGEs, with the one-loop RGEs of SM parameters being set

# %%
C_in = {"LH5_11": 1e-15+0j,"DLDH1_11": 1e-15+0j}       # Input the WCs
scale_in = 1e4                   # Input energy scale in unit of GeV
scale_out = 80                   # Output energy scale in unit of GeV
C_out = solve_rge(scale_in, scale_out, C_in, basis="down", method="integrate", rtol=1e-6, atol=1e-8, SM_loop='one')  ## the precision rtol=1e-6, atol=1e-8 is default, one can also set the lower precision for faster solution
print_WCs(C_out)
# Out:
# ## Wilson coefficients
#
# **EFT:** `SMEFT`
# | WC name | Value |
# |--------------------|----------------------------------------------------|
# | `LH5_11` | (5.517291279841112e-13-1.1696923502846581e-28j) |
# | `LH_11` | (-2.7271477267102412e-18+1.9641034995526026e-33j) |
# | `DLDH1_11` | (8.18337657671468e-16+3.09375363959948e-37j) |
# | `DLDH2_11` | (8.253541710427264e-17+2.9975479914431097e-38j) |
# | `QuLLH_3311` | (-2.9767908144120295e-17+6.616731328141741e-33j) |
# | `LHW_11` | (-3.3991905122524096e-18-1.1024480816112214e-33j) |
# | `QuLLH_2311` | (1.2327502355981069e-18-2.3090280472779516e-20j) |
# | `dLQLH1_3131` | (1.0357497559370927e-18-2.284316985862001e-34j) |
# | `duLDL_3311` | (-6.935157650831218e-19-1.581582405940985e-38j) |
# | `dLQLH2_3131` | (-5.3642122942914315e-19+1.1423303487614836e-34j) |
# | `QuLLH_1311` | (-2.5104202966972585e-19-1.0032005458286863e-19j) |
# | `eLLLHM_3113` | (-2.2230467129239076e-19-4.988069807221959e-29j) |
# ...

# %% [markdown]
# #### Set the RGEs of SM parameters at two-loop level

# %%
C_in = {"LH5_11": 1e-15+0j,"DLDH1_11": 1e-15+0j}       # Input the WCs
scale_in = 1e4                   # Input energy scale in unit of GeV
scale_out = 80                   # Output energy scale in unit of GeV
C_out = solve_rge(scale_in, scale_out, C_in, basis="down", method="integrate", rtol=1e-6, atol=1e-8, SM_loop='two')  ## the precision rtol=1e-6, atol=1e-8 is default, one can also set the lower precision for faster solution
print_WCs(C_out)
# Out:
# ## Wilson coefficients
#
# **EFT:** `SMEFT`
# | WC name | Value |
# |--------------------|----------------------------------------------------|
# | `LH5_11` | (5.560360251276046e-13-1.0813272658876569e-28j) |
# | `LH_11` | (-2.702201915772583e-18+1.814417363778076e-33j) |
# | `DLDH1_11` | (8.209099137149183e-16-2.4055480622526034e-37j) |
# | `DLDH2_11` | (8.289104314609275e-17-2.610795716405171e-38j) |
# | `QuLLH_3311` | (-2.9569627851055815e-17+6.0850593738693186e-33j) |
# | `LHW_11` | (-3.4158820873791977e-18-1.0184071826534807e-33j) |
# | `QuLLH_2311` | (1.2245392475417569e-18-2.293648288126068e-20j) |
# | `dLQLH1_3131` | (1.02600112239917e-18-2.098361277750983e-34j) |
# | `duLDL_3311` | (-6.779216142336866e-19-1.5014017452550473e-38j) |
# | `dLQLH2_3131` | (-5.313211202566823e-19+1.04928782659812e-34j) |
# | `QuLLH_1311` | (-2.4936991229475377e-19-9.965185210479614e-20j) |
# | `eLLLHM_3113` | (-2.2361874077198987e-19-4.643476305906158e-29j) |
# ...

# %% [markdown]
# ### Print the specific WCs in C_out

# %%
print_WCs(C_out,specific_keys=["LH5_11","LH_11"])
# Out:
# ## Wilson coefficients
#
# **EFT:** `SMEFT`
# | WC name | Value |
# |--------------------|----------------------------------------------------|
# | `LH5_11` | (5.560360251276046e-13-1.0813272658876569e-28j) |
# | `LH_11` | (-2.702201915772583e-18+1.814417363778076e-33j) |

# %% [markdown]
# #### Choose the up-quark flavor basis and leadinglog approxiamtion to solve the RGEs

# %%
C_in = {"LH5_11": 1e-15+0j,"DLDH1_11": 1e-15+0j}       
scale_in = 1e4                   
scale_out = 80                  
C_out = solve_rge(scale_in, scale_out, C_in, basis="up", method="leadinglog", SM_loop='one')  
print_WCs(C_out)
# Out:
# ## Wilson coefficients
#
# **EFT:** `SMEFT`
# | WC name | Value |
# |--------------------|----------------------------------------------------|
# | `LH5_11` | (7.082985962235545e-13+7.162468401290367e-41j) |
# | `LH_11` | (4.612168386065773e-18-2.0081796984992985e-45j) |
# | `DLDH1_11` | (8.462271005114665e-16+1.269519175320333e-41j) |
# | `DLDH2_11` | (9.567373264341764e-17+0j) |
# | `QuLLH_3311` | (-2.5700885724673575e-17-1.6769517444286556e-45j) |
# | `LHW_11` | (-3.7396953448012305e-18+0j) |
# | `dLQLH1_3131` | (7.718696362225865e-19+9.739852673343592e-46j) |
# | `duLDL_3311` | (-4.712157705615137e-19-8.204258739629873e-38j) |
# | `dLQLH2_3131` | (-4.0068957813142704e-19-5.05610957550204e-46j) |
# | `eLLLHM_3113` | (-2.562939253681956e-19+1.184995597301973e-47j) |
# | `QuLLH_2211` | (-9.106857920604253e-20-6.300972530841399e-48j) |
# | `eLLLHS_3113` | (8.338190591537493e-20-3.855229547966024e-48j) |
# | `dLQLH1_3121` | (3.469433437433763e-20-6.489721147225261e-46j) |
# ...

# %% [markdown]
# ### Plot the RG running of the WC itself

# %%
plot_WC(
    scale_initial=80, 
    scale_final=1e10, 
    C_in_initial={"LH5_11": 1e-15},  
    C_yaxis={"LH5_11"},
    number_points=10, 
    method='integrate', 
    basis="down",
    xscale='log', 
    yscale='log', 
    rtol=1e-6, 
    atol=1e-8, 
    mode='abs',
    SM_loop='one'
)

# %% [markdown]
# ### Plot the RG running of the SM paramater

# %%
plot_WC(
    scale_initial=1e2, 
    scale_final=1e20,  
    C_in_initial={},  
    C_yaxis={"gp", "g", "gs"},
    number_points=10, 
    method='integrate', 
    basis="down",
    legend_labels=None, 
    xlabel=None, 
    ylabel=r"SM parameters", 
    caption=r"RG evolution of SM parameters", 
    xscale='log', 
    yscale='linear', 
    rtol=1e-6, 
    atol=1e-8, 
    mode='abs',
    SM_loop='one'
    
)
